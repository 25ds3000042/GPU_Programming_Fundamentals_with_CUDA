# %% [markdown]
# <a href="https://colab.research.google.com/github/25ds3000042/GPU_Programming_Fundamentals_with_CUDA/blob/main/25ds3000042/GPU_Programming_Fundamentals_with_CUDA%20/Julia_set/Julia_Set_using_CUDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
